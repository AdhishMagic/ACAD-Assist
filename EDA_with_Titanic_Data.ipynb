# %% [markdown]
# <a href="https://colab.research.google.com/github/AdhishMagic/ACAD-Assist/blob/main/EDA_with_Titanic_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EDA with Titanic Data

# %% [markdown]
# ## Imports
